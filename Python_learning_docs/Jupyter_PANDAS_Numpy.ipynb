# %% [markdown]
# # This is jupyter notebook codes for practicing PANDAS and NUMPY

# %%
import pandas as pd

# %%
# %time
import numpy as np
# Out:
# Wall time: 0 ns

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# to print cells with border.

# %%HTML
<style type="text/css">
table.dataframe td, table.dataframe th {
    border: 1px  black solid !important;
  color: black !important;
}
</style>
# Out:
#   File "<ipython-input-54-8a03ce92fee9>", line 4
#     <style type="text/css">
#     ^
# SyntaxError: invalid syntax

# %%
 # %pprint
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# # pprint example: This is usedfpr prety print .ex-printing json data in readable format in python output console.

# %%
import requests 
from pprint import pprint 
  
def geocode(address): 
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    resp = requests.get(url, params = {'address': address}) 
    return resp.json() 
  
# calling geocode function 
data = geocode('India gate') 
  
# pretty-printing json response 
pprint(data)
# Out:
# {'error_message': 'You must use an API key to authenticate each request to '
#                   'Google Maps Platform APIs. For additional information, '
#                   'please refer to http://g.co/dev/maps-no-account',
#  'results': [],
#  'status': 'REQUEST_DENIED'}

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FE8C-C11A
#
#  Directory of C:\Users\pradeep\PycharmProjects\First_Project\Python_learning_docs
#
# 17-08-2020  15:31    <DIR>          .
# 17-08-2020  15:31    <DIR>          ..
# 11-08-2020  15:02    <DIR>          .ipynb_checkpoints
# 28-05-2020  16:21               158 How to create .exe file
# 28-05-2020  19:24             1,320 How to create CICD pipeline in azure devops
# 05-06-2020  01:35               456 How to run python egg
# 17-08-2020  15:31            68,585 Jupyter_PANDAS_Numpy.ipynb
# 15-05-2020  21:35               706 list input from user.txt
# 07-08-2020  00:31             1,374 Pyspark_Learning_Pycharm.txt
#                6 File(s)         72,599 bytes
#                3 Dir(s)  58,656,706,560 bytes free

# %%
! ls
# Out:
# How to create .exe file
# How to create CICD pipeline in azure devops
# How to run python egg
# Jupyter_PANDAS_Numpy.ipynb
# list input from user.txt
# Pyspark_Learning_Pycharm.txt

# %%
# %%HTML
# <h1>this is header in html format</h1>
# Out:
# <h1>this is header in html format</h1>

# %% [markdown]
# # Mat plot lib code

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)
data = np.random.randn(2, 100)

fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])

plt.show()

# %%
# !where python
# Out:
# C:\Users\pradeep\Anaconda3\python.exe
# C:\Program Files (x86)\Python38-32\python.exe
# C:\Users\pradeep\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
#!pip install pip-autoremove

# %%
#!pip uninstall pandas

# %%
#!pip install pandas --user

# %% [markdown]
# # PANDAS Practice

# %%
in_df=pd.read_csv("C:\\Users\\pradeep\\Desktop\\Proj_Pandas_Numpy\\Bengaluru_House_Data.csv") 
#header=0 for mentioning header num.
#header=None for mentioning  No header in data.

in_df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1      Super built-up  Area            NaN                       NaN
# 2                Plot  Area  Ready To Move          Chikka Tirupathi
# 3            Built-up  Area  Ready To Move               Uttarahalli
# 4      Super built-up  Area  Ready To Move        Lingadheeranahalli
# ...                     ...            ...                       ...
# 13316        Built-up  Area  Ready To Move                Whitefield
# 13317  Super built-up  Area  Ready To Move             Richards Town
# 13318        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13319  Super built-up  Area         18-Jun           Padmanabhanagar
# 13320  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
in_df.shape
# Out:
# (13320, 9)

# %%
in_df.set_index("area_type",inplace=True)
in_df
#seting the index to a perticular column.
# Out:
#                        availability                  location       size  \
# area_type
# Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# Super built-up  Area            NaN                       NaN        NaN
# Plot  Area            Ready To Move          Chikka Tirupathi  4 Bedroom
# Built-up  Area        Ready To Move               Uttarahalli      3 BHK
# Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# ...                             ...                       ...        ...
# Built-up  Area        Ready To Move                Whitefield  5 Bedroom
# Super built-up  Area  Ready To Move             Richards Town      4 BHK
# Built-up  Area        Ready To Move     Raja Rajeshwari Nagar      2 BHK
# Super built-up  Area         18-Jun           Padmanabhanagar      4 BHK
# Super built-up  Area  Ready To Move              Doddathoguru      1 BHK
#
#                       society total_sqft  bath  balcony   price
# area_type
# ...

# %%
in_df.columns
# Out:
# Index(['availability', 'location', 'size', 'society', 'total_sqft', 'bath',
#        'balcony', 'price'],
#       dtype='object')

# %%
in_df["area_type"]
# Out:
# 0        Super built-up  Area
# 1                  Plot  Area
# 2              Built-up  Area
# 3        Super built-up  Area
# 4        Super built-up  Area
#                  ...
# 13315          Built-up  Area
# 13316    Super built-up  Area
# 13317          Built-up  Area
# 13318    Super built-up  Area
# 13319    Super built-up  Area
# Name: area_type, Length: 13320, dtype: object

# %%
type(in_df['location']) 
#type(in_df.location)
# Out:
# <class 'pandas.core.series.Series'>

# %%
in_df[['location','size']]
# Out:
#                        location       size
# 0      Electronic City Phase II      2 BHK
# 1              Chikka Tirupathi  4 Bedroom
# 2                   Uttarahalli      3 BHK
# 3            Lingadheeranahalli      3 BHK
# 4                      Kothanur      2 BHK
# ...                         ...        ...
# 13315                Whitefield  5 Bedroom
# 13316             Richards Town      4 BHK
# 13317     Raja Rajeshwari Nagar      2 BHK
# 13318           Padmanabhanagar      4 BHK
# 13319              Doddathoguru      1 BHK
#
# [13320 rows x 2 columns]

# %%
in_df["price"].max()
# Out:
# 3600.0

# %%
in_df.describe()
#it gives the stats of numeric column.
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
in_df['price'].dtype
# Out:
# dtype('float64')

# %%
in_df[in_df.price<10.0]
#selection based on condition.
# Out:
#                   area_type          availability            location   size  \
# 8594         Built-up  Area         Ready To Move          Chandapura  1 BHK
# 10526  Super built-up  Area         Ready To Move  Yelahanka New Town  1 BHK
# 11569            Plot  Area  Immediate Possession          Hosur Road    NaN
#
#        society total_sqft  bath  balcony  price
# 8594       NaN        450   1.0      1.0   9.00
# 10526  KHatsFl        284   1.0      1.0   8.00
# 11569  AVeldun       1350   NaN      NaN   8.44

# %%
in_df_na=in_df[in_df.isnull().any(axis=1)]
in_df_na

#records having any rows as NaN.
# Out:
#                   area_type   availability          location       size  \
# 2            Built-up  Area  Ready To Move       Uttarahalli      3 BHK
# 4      Super built-up  Area  Ready To Move          Kothanur      2 BHK
# 6      Super built-up  Area         18-May  Old Airport Road      4 BHK
# 7      Super built-up  Area  Ready To Move      Rajaji Nagar      4 BHK
# 8      Super built-up  Area  Ready To Move      Marathahalli      3 BHK
# ...                     ...            ...               ...        ...
# 13310  Super built-up  Area  Ready To Move      Rachenahalli      2 BHK
# 13311            Plot  Area  Ready To Move  Ramamurthy Nagar  7 Bedroom
# 13312  Super built-up  Area  Ready To Move         Bellandur      2 BHK
# 13316  Super built-up  Area  Ready To Move     Richards Town      4 BHK
# 13319  Super built-up  Area  Ready To Move      Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony   price
# 2          NaN       1440   2.0      3.0   62.00
# ...

# %%
#fetching rows with all null values.
in_df_all_row_na=in_df[in_df.isnull().all(axis=1)]
in_df_all_row_na
# Out:
#                      availability location size society total_sqft  bath  \
# area_type
# Super built-up  Area          NaN      NaN  NaN     NaN        NaN   NaN
#
#                       balcony  price
# area_type
# Super built-up  Area      NaN    NaN

# %%
# fill na
in_df_all_row_na.fillna(1,inplace=True)
in_df_all_row_na
# Out:
# C:\Users\pradeep\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#                       availability  location  size  society  total_sqft  bath  \
# area_type
# Super built-up  Area             1         1     1        1           1   1.0
#
#                       balcony  price
# area_type
# Super built-up  Area      1.0    1.0

# %%
#removing rows having Nan.
df1=in_df.dropna()

# %%
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1[df1.price<10.0]
# Out:
#                   area_type   availability            location   size  \
# 10526  Super built-up  Area  Ready To Move  Yelahanka New Town  1 BHK
#
#        society total_sqft  bath  balcony  price
# 10526  KHatsFl        284   1.0      1.0    8.0

# %%
df1[df1.price==df1["price"].max()]
# Out:
#                  area_type   availability         location   size  society  \
# 3180  Super built-up  Area  Ready To Move  Shanthala Nagar  5 BHK  Kierser
#
#      total_sqft  bath  balcony   price
# 3180       8321   5.0      3.0  2700.0

# %%
df1["price"].max()
# Out:
# 2700.0

# %%
in_df["price"].max()
# Out:
# 3600.0

# %%
df1["location"][df1.price==df1["price"].max()]
# Out:
# 3180    Shanthala Nagar
# Name: location, dtype: object

# %%
df1.to_sql?

#use ? mark to know the defnition of file

# %%
#df1.to_csv("C:\\Users\\pradeep\\Desktop\\Proj_Pandas_Numpy\\Bengaluru_House_Data_out.csv",index=False)

#for saving output to a file 
#removing index number.

# %%
sizedf=df1.set_index('size')

# %%
sizedf
# Out:
#                       area_type   availability                  location  \
# size
# 2 BHK      Super built-up  Area         19-Dec  Electronic City Phase II
# 4 Bedroom            Plot  Area  Ready To Move          Chikka Tirupathi
# 3 BHK      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 2 BHK      Super built-up  Area  Ready To Move                Whitefield
# 4 Bedroom            Plot  Area  Ready To Move                Whitefield
# ...                         ...            ...                       ...
# 3 BHK      Super built-up  Area  Ready To Move               Uttarahalli
# 3 BHK      Super built-up  Area  Ready To Move         Green Glen Layout
# 5 Bedroom        Built-up  Area  Ready To Move                Whitefield
# 2 BHK            Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 4 BHK      Super built-up  Area         18-Jun           Padmanabhanagar
#
#            society total_sqft  bath  balcony   price
# size
# ...

# %%
sizedf.loc['2 BHK']
# Out:
#                   area_type   availability                  location  society  \
# size
# 2 BHK  Super built-up  Area         19-Dec  Electronic City Phase II  Coomee
# 2 BHK  Super built-up  Area  Ready To Move                Whitefield  DuenaTa
# 2 BHK  Super built-up  Area  Ready To Move        7th Phase JP Nagar  Shncyes
# 2 BHK  Super built-up  Area  Ready To Move               Mysore Road  PrntaEn
# 2 BHK  Super built-up  Area  Ready To Move           Electronic City  Itelaa
# ...                     ...            ...                       ...      ...
# 2 BHK  Super built-up  Area  Ready To Move                    Hebbal  Prersis
# 2 BHK  Super built-up  Area  Ready To Move           Electronic City  GMown E
# 2 BHK  Super built-up  Area  Ready To Move             Kenchenahalli  AriosPa
# 2 BHK  Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar  GrrvaGr
# 2 BHK        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  Mahla T
#
# ...

# %%
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# to replace a value with NaN

df1.replace('Ready To Move',np.NaN)
# Out:
#                   area_type availability                  location       size  \
# 0      Super built-up  Area       19-Dec  Electronic City Phase II      2 BHK
# 1                Plot  Area          NaN          Chikka Tirupathi  4 Bedroom
# 3      Super built-up  Area          NaN        Lingadheeranahalli      3 BHK
# 5      Super built-up  Area          NaN                Whitefield      2 BHK
# 11               Plot  Area          NaN                Whitefield  4 Bedroom
# ...                     ...          ...                       ...        ...
# 13313  Super built-up  Area          NaN               Uttarahalli      3 BHK
# 13314  Super built-up  Area          NaN         Green Glen Layout      3 BHK
# 13315        Built-up  Area          NaN                Whitefield  5 Bedroom
# 13317        Built-up  Area          NaN     Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area       18-Jun           Padmanabhanagar      4 BHK
#
# ...

# %%
# to replace multiple value with NaN

df1.replace(['Ready To Move','2 BHK'],np.NaN)
# Out:
#                   area_type availability                  location       size  \
# 0      Super built-up  Area       19-Dec  Electronic City Phase II        NaN
# 1                Plot  Area          NaN          Chikka Tirupathi  4 Bedroom
# 3      Super built-up  Area          NaN        Lingadheeranahalli      3 BHK
# 5      Super built-up  Area          NaN                Whitefield        NaN
# 11               Plot  Area          NaN                Whitefield  4 Bedroom
# ...                     ...          ...                       ...        ...
# 13313  Super built-up  Area          NaN               Uttarahalli      3 BHK
# 13314  Super built-up  Area          NaN         Green Glen Layout      3 BHK
# 13315        Built-up  Area          NaN                Whitefield  5 Bedroom
# 13317        Built-up  Area          NaN     Raja Rajeshwari Nagar        NaN
# 13318  Super built-up  Area       18-Jun           Padmanabhanagar      4 BHK
#
# ...

# %%
# to replace multiple value from diffrent columns with NaN

df1.replace({'availability':'Ready To Move',
             'size':'2 BHK'},np.NaN)
# Out:
#                   area_type availability                  location       size  \
# 0      Super built-up  Area       19-Dec  Electronic City Phase II        NaN
# 1                Plot  Area          NaN          Chikka Tirupathi  4 Bedroom
# 3      Super built-up  Area          NaN        Lingadheeranahalli      3 BHK
# 5      Super built-up  Area          NaN                Whitefield        NaN
# 11               Plot  Area          NaN                Whitefield  4 Bedroom
# ...                     ...          ...                       ...        ...
# 13313  Super built-up  Area          NaN               Uttarahalli      3 BHK
# 13314  Super built-up  Area          NaN         Green Glen Layout      3 BHK
# 13315        Built-up  Area          NaN                Whitefield  5 Bedroom
# 13317        Built-up  Area          NaN     Raja Rajeshwari Nagar        NaN
# 13318  Super built-up  Area       18-Jun           Padmanabhanagar      4 BHK
#
# ...

# %%
# to replace multiple value using regex

df1.replace({'availability':'[A-Za-z]',
             'size':'[A-Za-z]'},'',regex=True)
# Out:
#                   area_type availability                  location size  \
# 0      Super built-up  Area          19-  Electronic City Phase II   2
# 1                Plot  Area                       Chikka Tirupathi   4
# 3      Super built-up  Area                     Lingadheeranahalli   3
# 5      Super built-up  Area                             Whitefield   2
# 11               Plot  Area                             Whitefield   4
# ...                     ...          ...                       ...  ...
# 13313  Super built-up  Area                            Uttarahalli   3
# 13314  Super built-up  Area                      Green Glen Layout   3
# 13315        Built-up  Area                             Whitefield   5
# 13317        Built-up  Area                  Raja Rajeshwari Nagar   2
# 13318  Super built-up  Area          18-           Padmanabhanagar   4
#
#        society total_sqft  bath  balcony   price
# 0      Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1.drop(df1[df1['availability']=='Ready To Move'].index)

# %% [markdown]
# # group by

# %%
df1.groupby('location').max('price')
# Out:
#                                 bath  balcony    price
# location
#  Banaswadi                       1.0      0.0    35.00
#  Bhoganhalli                     1.0      0.0    22.89
#  Devarabeesana Halli             3.0      3.0   160.00
#  Devarachikkanahalli             3.0      2.0    75.00
#  Electronic City                 1.0      1.0    27.00
# ...                              ...      ...      ...
# Yelahanka New Town               3.0      3.0   130.00
# Yelenahalli                      2.0      2.0    60.00
# Yemlur                           5.0      3.0  2000.00
# Yeshwanthpur                     4.0      3.0   180.00
# Yeshwanthpur Industrial Suburb   2.0      2.0   120.00
#
# [634 rows x 3 columns]

# %%
g=df1.groupby('location')


for location,location_df in g:
    print(location)
    print(location_df)
# Out:
#  Banaswadi
#                  area_type   availability    location  size  society  \
# 8385  Super built-up  Area  Ready To Move   Banaswadi  1 RK  Krntsee
#
#      total_sqft  bath  balcony  price
# 8385        527   1.0      0.0   35.0
#  Bhoganhalli
#                  area_type availability      location  size  society  \
# 2486  Super built-up  Area       19-Dec   Bhoganhalli  1 RK  Rosha I
#
#      total_sqft  bath  balcony  price
# 2486        296   1.0      0.0  22.89
#  Devarabeesana Halli
#                  area_type   availability              location   size  \
# 3281  Super built-up  Area  Ready To Move   Devarabeesana Halli  3 BHK
# 3620        Built-up  Area  Ready To Move   Devarabeesana Halli  3 BHK
# 6000  Super built-up  Area  Ready To Move   Devarabeesana Halli  3 BHK
# 6120  Super built-up  Area  Ready To Move   Devarabeesana Halli  3 BHK
#
#       society total_sqft  bath  balcony  price
# 3281  Sorisa        1672   3.0      2.0  150.0
# ...

# %%
g_baswan=g.get_group('Banaswadi')
g_baswan
# Out:
#                   area_type   availability   size  society total_sqft  bath  \
# 7856   Super built-up  Area  Ready To Move  2 BHK  RailsDa        870   2.0
# 8287   Super built-up  Area  Ready To Move  3 BHK  Srldsri       1600   3.0
# 10143  Super built-up  Area  Ready To Move  2 BHK  Naavehi       1008   2.0
# 12187        Built-up  Area  Ready To Move  2 BHK  Shidei        1105   2.0
#
#        balcony  price
# 7856       2.0   38.0
# 8287       2.0   74.5
# 10143      2.0   52.0
# 12187      2.0   57.0

# %%
g.max()
#max of each vaule
# Out:
#                                            area_type   availability  \
# location
#  Banaswadi                      Super built-up  Area  Ready To Move
#  Bhoganhalli                    Super built-up  Area         19-Dec
#  Devarabeesana Halli            Super built-up  Area  Ready To Move
#  Devarachikkanahalli            Super built-up  Area  Ready To Move
#  Electronic City                      Built-up  Area  Ready To Move
# ...                                              ...            ...
# Yelahanka New Town              Super built-up  Area  Ready To Move
# Yelenahalli                     Super built-up  Area  Ready To Move
# Yemlur                          Super built-up  Area  Ready To Move
# Yeshwanthpur                    Super built-up  Area  Ready To Move
# Yeshwanthpur Industrial Suburb  Super built-up  Area  Ready To Move
#
#                                      size  society total_sqft  bath  balcony  \
# location
# ...

# %%
# %matplotlib inline
g_baswan.plot()
